# %%
#Loading the test data
import pandas as pd
test = pd.read_csv("data/test.csv", index_col='Index')

# %%
test.head()
# Out:
#                                          LossDescription ResultingInjuryDesc  \
# Index
# 5                                                    NaN                 NaN
# 17                                                   NaN                 NaN
# 20                                                   NaN                 NaN
# 47     EE was getting out of the truck and twisted he...                 NaN
# 48     Worker was making a delivery and her right han...                 NaN
#
#       PartInjuredDesc  Cause - Hierarchy 1  Body Part - Hierarchy 1
# Index
# 5               Thumb                  NaN                      NaN
# 17          Lower Arm                  NaN                      NaN
# 20            Abdomen                  NaN                      NaN
# 47                NaN                  NaN                      NaN
# 48                NaN                  NaN                      NaN

# %%
#Function to merge columns
def merge_cols(row):
    txt = ""
    for i in row:
        if isinstance(i, str):
            txt = txt+', '+i
    return txt[2:]

# %%
#Function to preprocess the data and saves it as a csv file
def preprocess(test):
    test['description'] = test.iloc[:, :4].apply(lambda x : merge_cols(x), axis=1)
    test = test.drop(columns=['LossDescription','ResultingInjuryDesc','PartInjuredDesc'])
    for columns in test.columns:
        test.loc[:, columns] = test.loc[:, columns].apply(lambda x: x.lower() if isinstance(x, str) else x)
    test.iloc[:, 2].to_csv("./data/preprocess_test.csv")

# %%
#Calling the function
preprocess(test)
test[['description']].head()
# Out:
#                                              description
# Index
# 5                                                  Thumb
# 17                                             Lower Arm
# 20                                               Abdomen
# 47     EE was getting out of the truck and twisted he...
# 48     Worker was making a delivery and her right han...

# %%
from datasets import load_dataset
from transformers import AutoTokenizer, DataCollatorWithPadding
#Loading the data
test = load_dataset("csv", data_files="data/preprocess_test.csv")


#Loading the tokenizer for the bert-base-uncased model
checkpoint = "bert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(checkpoint)

#Function to Tokenize the data
def tokenize_function(example):
    return tokenizer(example["description"], truncation=True)

#Tokenizing the data
tokenized_test = test.map(tokenize_function, batched=True)
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/435 [00:00<?, ? examples/s]

# %%
#Preprocessing the tokenized data
tokenized_test = tokenized_test.remove_columns(["description", "Index"])
tokenized_test.set_format("torch")
tokenized_test["train"].column_names
# Out:
# ['input_ids', 'token_type_ids', 'attention_mask']

# %%
from torch.utils.data import DataLoader
import torch

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
#Loading the test set into a dataloader of single batch
dataloader = DataLoader(
    tokenized_test["train"], batch_size=tokenized_test["train"].num_rows, collate_fn=data_collator, shuffle=False
)

# %%
from transformers import AutoModelForSequenceClassification
#Loading the saved models for the classification task
cause_model = AutoModelForSequenceClassification.from_pretrained("cause_model").to(device)
bodypart_model = AutoModelForSequenceClassification.from_pretrained("bodypart_model").to(device)

# %%
#Prediction function that returns the prediction
def prediction(model, data_loader):
    for batch in data_loader:
        batch = {k: v.to(device) for k, v in batch.items()}
        with torch.no_grad():
            outputs = model(**batch)  
    logits = outputs.logits
    predictions = torch.argmax(logits, dim=-1)  
    return predictions

# %%
#Running Inference to get predictions
cause_preds = prediction(cause_model, dataloader)
bodypart_preds = prediction(bodypart_model, dataloader)

# %%
print(cause_preds.shape, bodypart_preds.shape)
# Out:
# torch.Size([435]) torch.Size([435])

# %%
#Labels
causes = ['burn or scald - heat or cold exposures - contact with',
 'caught in, under or between',
 'cut, puncture, scrape injured by',
 'fall, slip or trip injury',
 'fall, slip, or trip injury',
 'includes freezing',
 'misc',
 'motor vehicle',
 'rubbed or abraded by',
 'strain or injury by',
 'striking against or stepping on',
 'struck or injured by']
bodyparts = ['head',
 'lower extremities',
 'misc',
 'multiple body parts',
 'neck',
 'trunk',
 'upper extremities']

# %%
#Loading the test data
test = pd.read_csv("./data/test.csv")

# %%
test.head()
# Out:
#                                      LossDescription ResultingInjuryDesc  \
# 0                                                NaN                 NaN
# 1                                                NaN                 NaN
# 2                                                NaN                 NaN
# 3  EE was getting out of the truck and twisted he...                 NaN
# 4  Worker was making a delivery and her right han...                 NaN
#
#   PartInjuredDesc  Cause - Hierarchy 1  Body Part - Hierarchy 1  Index
# 0           Thumb                  NaN                      NaN      5
# 1       Lower Arm                  NaN                      NaN     17
# 2         Abdomen                  NaN                      NaN     20
# 3             NaN                  NaN                      NaN     47
# 4             NaN                  NaN                      NaN     48

# %%
#Replacing the nan values with the predicted values
test.loc[:, 'Cause - Hierarchy 1'] = pd.Series([causes[i] for i in cause_preds])
test.loc[:, 'Body Part - Hierarchy 1'] = pd.Series([bodyparts[i] for i in bodypart_preds])
# Out:
# C:\Users\gowth\AppData\Local\Temp\ipykernel_9328\876233129.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['caught in, under or between' 'caught in, under or between' 'misc'
#  'caught in, under or between' 'includes freezing'
#  'caught in, under or between' 'strain or injury by' 'misc'
#  'rubbed or abraded by' 'includes freezing' 'caught in, under or between'
#  'caught in, under or between' 'fall, slip or trip injury'
#  'caught in, under or between' 'misc' 'rubbed or abraded by'
#  'caught in, under or between' 'caught in, under or between' 'misc'
#  'caught in, under or between' 'fall, slip or trip injury'
#  'caught in, under or between' 'fall, slip or trip injury'
#  'caught in, under or between' 'caught in, under or between'
#  'caught in, under or between' 'caught in, under or between'
#  'includes freezing' 'caught in, under or between'
#  'fall, slip or trip injury' 'caught in, under or between'
#  'fall, slip or trip injury' 'fall, slip or trip injury'
#  'caught in, under or between' 'struck or injured by'
#  'fall, slip or trip injury' 'struck or injured by' 'struck or injured by'
#  'motor vehicle' 'struck or injured by' 'struck or injured by'
#  'strain or injury by' 'misc' 'strain or injury by' 'struck or injured by'
#  'struck or injured by' 'struck or injured by' 'fall, slip or trip injury'
#  'struck or injured by' 'struck or injured by' 'struck or injured by'
#  'burn or scald - heat or cold exposures - contact with'
#  'struck or injured by' 'fall, slip or trip injury' 'motor vehicle'
#  'fall, slip or trip injury' 'striking against or stepping on'
#  'struck or injured by' 'fall, slip or trip injury' 'strain or injury by'
#  'fall, slip or trip injury' 'strain or injury by' 'struck or injured by'
#  'struck or injured by' 'struck or injured by' 'fall, slip or trip injury'
#  'cut, puncture, scrape injured by' 'struck or injured by'
#  'struck or injured by' 'cut, puncture, scrape injured by'
#  'struck or injured by' 'struck or injured by' 'struck or injured by'
#  'fall, slip or trip injury' 'fall, slip or trip injury'
#  'fall, slip or trip injury' 'struck or injured by' 'struck or injured by'
#  'motor vehicle' 'fall, slip or trip injury' 'motor vehicle'
#  'struck or injured by' 'caught in, under or between'
#  'caught in, under or between' 'caught in, under or between'
#  'caught in, under or between' 'struck or injured by'
#  'caught in, under or between' 'caught in, under or between'
#  'caught in, under or between' 'caught in, under or between'
#  'strain or injury by' 'caught in, under or between'
#  'fall, slip or trip injury' 'fall, slip or trip injury'
#  'strain or injury by' 'caught in, under or between'
#  'caught in, under or between' 'caught in, under or between'
#  'caught in, under or between' 'caught in, under or between'
#  'caught in, under or between' 'caught in, under or between'
#  'caught in, under or between' 'caught in, under or between'
#  'caught in, under or between' 'caught in, under or between'
#  'caught in, under or between' 'caught in, under or between'
#  'caught in, under or between' 'caught in, under or between'
#  'caught in, under or between' 'rubbed or abraded by'
#  'fall, slip or trip injury' 'caught in, under or between'
#  'struck or injured by' 'motor vehicle' 'caught in, under or between'
#  'caught in, under or between' 'strain or injury by'
#  'caught in, under or between' 'caught in, under or between' 'misc' 'misc'
#  'striking against or stepping on' 'caught in, under or between'
#  'cut, puncture, scrape injured by' 'caught in, under or between'
#  'caught in, under or between' 'caught in, under or between'
#  'caught in, under or between' 'cut, puncture, scrape injured by'
#  'caught in, under or between' 'misc' 'struck or injured by'
#  'motor vehicle' 'struck or injured by' 'caught in, under or between'
#  'caught in, under or between' 'caught in, under or between'
#  'fall, slip or trip injury' 'fall, slip or trip injury'
#  'struck or injured by' 'struck or injured by' 'misc'
#  'fall, slip or trip injury' 'striking against or stepping on'
#  'motor vehicle' 'cut, puncture, scrape injured by'
#  'striking against or stepping on' 'cut, puncture, scrape injured by'
#  'fall, slip or trip injury' 'cut, puncture, scrape injured by'
#  'fall, slip or trip injury' 'misc' 'cut, puncture, scrape injured by'
#  'cut, puncture, scrape injured by' 'caught in, under or between' 'misc'
#  'cut, puncture, scrape injured by' 'motor vehicle'
#  'cut, puncture, scrape injured by' 'includes freezing'
#  'cut, puncture, scrape injured by' 'strain or injury by'
#  'caught in, under or between' 'motor vehicle' 'motor vehicle'
#  'motor vehicle' 'misc' 'striking against or stepping on'
#  'caught in, under or between' 'includes freezing' 'motor vehicle'
#  'includes freezing' 'cut, puncture, scrape injured by'
#  'caught in, under or between' 'fall, slip or trip injury' 'motor vehicle'
#  'cut, puncture, scrape injured by' 'caught in, under or between'
#  'rubbed or abraded by' 'striking against or stepping on'
#  'cut, puncture, scrape injured by' 'caught in, under or between'
#  'fall, slip or trip injury' 'motor vehicle' 'includes freezing'
#  'motor vehicle' 'cut, puncture, scrape injured by' 'motor vehicle'
#  'cut, puncture, scrape injured by' 'motor vehicle' 'motor vehicle'
#  'cut, puncture, scrape injured by' 'rubbed or abraded by' 'motor vehicle'
#  'caught in, under or between' 'motor vehicle'
#  'striking against or stepping on' 'caught in, under or between'
#  'caught in, under or between' 'strain or injury by'
#  'caught in, under or between' 'caught in, under or between'
#  'caught in, under or between' 'includes freezing'
#  'caught in, under or between' 'caught in, under or between'
#  'fall, slip or trip injury' 'strain or injury by' 'misc'
#  'caught in, under or between' 'caught in, under or between'
#  'caught in, under or between' 'fall, slip or trip injury'
#  'caught in, under or between' 'caught in, under or between'
#  'strain or injury by' 'caught in, under or between'
#  'caught in, under or between' 'caught in, under or between'
#  'striking against or stepping on' 'striking against or stepping on'
#  'caught in, under or between' 'misc' 'cut, puncture, scrape injured by'
#  'caught in, under or between' 'fall, slip or trip injury'
#  'struck or injured by' 'misc' 'misc' 'cut, puncture, scrape injured by'
#  'caught in, under or between' 'caught in, under or between'
#  'motor vehicle' 'caught in, under or between' 'motor vehicle'
#  'motor vehicle' 'motor vehicle' 'misc' 'caught in, under or between'
#  'caught in, under or between' 'cut, puncture, scrape injured by'
#  'cut, puncture, scrape injured by' 'caught in, under or between'
#  'fall, slip or trip injury' 'caught in, under or between'
#  'caught in, under or between' 'caught in, under or between'
#  'caught in, under or between' 'caught in, under or between'
#  'struck or injured by' 'cut, puncture, scrape injured by'
#  'includes freezing' 'misc' 'caught in, under or between'
#  'cut, puncture, scrape injured by' 'strain or injury by'
#  'strain or injury by' 'caught in, under or between'
#  'fall, slip or trip injury' 'motor vehicle' 'struck or injured by'
#  'caught in, under or between' 'struck or injured by'
#  'struck or injured by' 'fall, slip or trip injury'
#  'caught in, under or between' 'caught in, under or between'
#  'caught in, under or between' 'caught in, under or between'
#  'caught in, under or between' 'includes freezing' 'struck or injured by'
#  'fall, slip or trip injury' 'strain or injury by' 'motor vehicle'
#  'caught in, under or between' 'striking against or stepping on'
#  'strain or injury by' 'caught in, under or between' 'motor vehicle'
#  'caught in, under or between' 'caught in, under or between'
#  'caught in, under or between' 'caught in, under or between'
#  'strain or injury by' 'fall, slip or trip injury'
#  'striking against or stepping on' 'motor vehicle' 'includes freezing'
#  'motor vehicle' 'caught in, under or between'
#  'striking against or stepping on' 'struck or injured by'
#  'fall, slip or trip injury' 'cut, puncture, scrape injured by'
#  'struck or injured by' 'caught in, under or between'
#  'strain or injury by' 'strain or injury by' 'caught in, under or between'
#  'caught in, under or between' 'rubbed or abraded by'
#  'struck or injured by' 'caught in, under or between'
#  'caught in, under or between' 'strain or injury by'
#  'caught in, under or between' 'caught in, under or between'
#  'rubbed or abraded by' 'caught in, under or between'
#  'caught in, under or between' 'caught in, under or between'
#  'caught in, under or between' 'caught in, under or between'
#  'cut, puncture, scrape injured by' 'fall, slip or trip injury'
#  'striking against or stepping on' 'caught in, under or between'
#  'caught in, under or between' 'caught in, under or between'
#  'caught in, under or between' 'fall, slip or trip injury'
#  'caught in, under or between' 'caught in, under or between'
#  'caught in, under or between' 'caught in, under or between'
#  'caught in, under or between' 'caught in, under or between'
#  'caught in, under or between' 'caught in, under or between'
#  'cut, puncture, scrape injured by' 'caught in, under or between'
#  'caught in, under or between' 'caught in, under or between' 'misc'
#  'fall, slip or trip injury' 'misc' 'misc' 'caught in, under or between'
#  'misc' 'strain or injury by' 'caught in, under or between'
#  'caught in, under or between' 'caught in, under or between'
#  'caught in, under or between' 'caught in, under or between'
#  'caught in, under or between' 'motor vehicle'
#  'caught in, under or between' 'caught in, under or between'
#  'caught in, under or between' 'caught in, under or between'
#  'caught in, under or between' 'misc' 'caught in, under or between'
#  'motor vehicle' 'fall, slip or trip injury' 'caught in, under or between'
#  'caught in, under or between' 'caught in, under or between'
#  'rubbed or abraded by' 'rubbed or abraded by' 'fall, slip or trip injury'
#  'rubbed or abraded by' 'rubbed or abraded by' 'rubbed or abraded by'
#  'striking against or stepping on' 'fall, slip or trip injury'
#  'fall, slip or trip injury' 'rubbed or abraded by' 'rubbed or abraded by'
#  'includes freezing' 'strain or injury by' 'misc'
#  'caught in, under or between' 'fall, slip or trip injury'
#  'struck or injured by' 'caught in, under or between'
#  'caught in, under or between' 'caught in, under or between'
#  'includes freezing' 'caught in, under or between'
#  'caught in, under or between' 'strain or injury by'
#  'caught in, under or between' 'caught in, under or between'
#  'caught in, under or between' 'strain or injury by' 'includes freezing'
#  'caught in, under or between' 'caught in, under or between'
#  'fall, slip or trip injury' 'cut, puncture, scrape injured by'
#  'caught in, under or between' 'motor vehicle'
#  'caught in, under or between' 'caught in, under or between'
#  'motor vehicle' 'caught in, under or between' 'rubbed or abraded by'
#  'strain or injury by' 'motor vehicle' 'includes freezing'
#  'includes freezing' 'caught in, under or between'
#  'caught in, under or between' 'caught in, under or between'
#  'caught in, under or between' 'caught in, under or between'
#  'caught in, under or between' 'fall, slip or trip injury'
#  'fall, slip or trip injury' 'struck or injured by'
#  'fall, slip or trip injury' 'fall, slip or trip injury'
#  'struck or injured by' 'struck or injured by' 'fall, slip or trip injury'
#  'fall, slip or trip injury' 'struck or injured by'
#  'caught in, under or between' 'fall, slip or trip injury'
#  'fall, slip or trip injury' 'struck or injured by' 'motor vehicle'
#  'motor vehicle' 'motor vehicle' 'struck or injured by'
#  'struck or injured by' 'caught in, under or between'
#  'caught in, under or between' 'cut, puncture, scrape injured by']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   test.loc[:, 'Cause - Hierarchy 1'] = pd.Series([causes[i] for i in cause_preds])
# C:\Users\gowth\AppData\Local\Temp\ipykernel_9328\876233129.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['upper extremities' 'upper extremities' 'trunk' 'lower extremities'
#  'upper extremities' 'misc' 'trunk' 'upper extremities' 'trunk' 'neck'
#  'head' 'upper extremities' 'lower extremities' 'head'
#  'multiple body parts' 'upper extremities' 'lower extremities'
#  'upper extremities' 'misc' 'upper extremities' 'lower extremities'
#  'lower extremities' 'lower extremities' 'lower extremities'
#  'lower extremities' 'upper extremities' 'trunk' 'neck'
#  'lower extremities' 'lower extremities' 'upper extremities'
#  'multiple body parts' 'multiple body parts' 'trunk' 'multiple body parts'
#  'lower extremities' 'head' 'multiple body parts' 'multiple body parts'
#  'lower extremities' 'upper extremities' 'lower extremities' 'trunk'
#  'lower extremities' 'head' 'multiple body parts' 'multiple body parts'
#  'lower extremities' 'head' 'head' 'head' 'upper extremities'
#  'multiple body parts' 'trunk' 'trunk' 'multiple body parts'
#  'lower extremities' 'upper extremities' 'lower extremities'
#  'upper extremities' 'lower extremities' 'lower extremities'
#  'upper extremities' 'head' 'lower extremities' 'lower extremities'
#  'upper extremities' 'upper extremities' 'head' 'upper extremities'
#  'multiple body parts' 'neck' 'multiple body parts' 'lower extremities'
#  'multiple body parts' 'lower extremities' 'head' 'head' 'trunk'
#  'upper extremities' 'trunk' 'lower extremities' 'head' 'misc'
#  'upper extremities' 'upper extremities' 'upper extremities'
#  'upper extremities' 'head' 'head' 'trunk' 'neck' 'lower extremities'
#  'head' 'lower extremities' 'multiple body parts' 'head'
#  'lower extremities' 'trunk' 'head' 'upper extremities'
#  'upper extremities' 'upper extremities' 'upper extremities'
#  'upper extremities' 'head' 'lower extremities' 'trunk' 'trunk' 'neck'
#  'head' 'upper extremities' 'upper extremities' 'upper extremities'
#  'lower extremities' 'upper extremities' 'misc' 'lower extremities'
#  'trunk' 'misc' 'lower extremities' 'upper extremities' 'trunk'
#  'multiple body parts' 'trunk' 'multiple body parts' 'upper extremities'
#  'upper extremities' 'head' 'misc' 'upper extremities' 'upper extremities'
#  'misc' 'misc' 'misc' 'misc' 'misc' 'trunk' 'lower extremities'
#  'upper extremities' 'misc' 'lower extremities' 'misc' 'misc' 'head'
#  'misc' 'multiple body parts' 'neck' 'upper extremities'
#  'upper extremities' 'upper extremities' 'upper extremities'
#  'upper extremities' 'upper extremities' 'multiple body parts'
#  'upper extremities' 'upper extremities' 'upper extremities' 'misc' 'misc'
#  'misc' 'upper extremities' 'upper extremities' 'upper extremities' 'misc'
#  'upper extremities' 'misc' 'misc' 'misc' 'misc' 'misc' 'head'
#  'upper extremities' 'misc' 'misc' 'upper extremities' 'trunk' 'misc'
#  'misc' 'upper extremities' 'upper extremities' 'misc' 'lower extremities'
#  'upper extremities' 'upper extremities' 'misc' 'misc' 'upper extremities'
#  'misc' 'upper extremities' 'misc' 'upper extremities' 'misc' 'misc'
#  'upper extremities' 'upper extremities' 'misc' 'lower extremities' 'misc'
#  'lower extremities' 'upper extremities' 'head' 'lower extremities' 'neck'
#  'neck' 'upper extremities' 'head' 'upper extremities' 'upper extremities'
#  'lower extremities' 'lower extremities' 'upper extremities' 'misc' 'misc'
#  'misc' 'misc' 'trunk' 'trunk' 'lower extremities' 'upper extremities'
#  'trunk' 'trunk' 'lower extremities' 'lower extremities'
#  'lower extremities' 'upper extremities' 'upper extremities' 'neck' 'misc'
#  'misc' 'misc' 'head' 'upper extremities' 'trunk' 'lower extremities'
#  'misc' 'head' 'misc' 'misc' 'misc' 'misc' 'misc' 'misc' 'misc' 'head'
#  'head' 'lower extremities' 'lower extremities' 'multiple body parts'
#  'lower extremities' 'trunk' 'trunk' 'lower extremities'
#  'upper extremities' 'head' 'head' 'lower extremities' 'upper extremities'
#  'upper extremities' 'upper extremities' 'multiple body parts'
#  'multiple body parts' 'multiple body parts' 'multiple body parts' 'trunk'
#  'multiple body parts' 'multiple body parts' 'lower extremities'
#  'upper extremities' 'upper extremities' 'upper extremities'
#  'upper extremities' 'upper extremities' 'lower extremities' 'trunk'
#  'lower extremities' 'lower extremities' 'head' 'head' 'lower extremities'
#  'misc' 'lower extremities' 'misc' 'multiple body parts' 'misc' 'trunk'
#  'lower extremities' 'lower extremities' 'lower extremities' 'misc'
#  'trunk' 'misc' 'trunk' 'upper extremities' 'upper extremities' 'head'
#  'upper extremities' 'upper extremities' 'multiple body parts'
#  'multiple body parts' 'trunk' 'trunk' 'multiple body parts'
#  'lower extremities' 'upper extremities' 'upper extremities'
#  'lower extremities' 'head' 'lower extremities' 'trunk'
#  'lower extremities' 'upper extremities' 'trunk' 'upper extremities'
#  'trunk' 'lower extremities' 'lower extremities' 'upper extremities'
#  'trunk' 'misc' 'multiple body parts' 'lower extremities' 'trunk' 'head'
#  'lower extremities' 'head' 'upper extremities' 'head' 'trunk'
#  'upper extremities' 'lower extremities' 'upper extremities'
#  'lower extremities' 'upper extremities' 'lower extremities'
#  'upper extremities' 'upper extremities' 'upper extremities'
#  'lower extremities' 'trunk' 'trunk' 'head' 'misc' 'trunk'
#  'lower extremities' 'trunk' 'trunk' 'multiple body parts' 'trunk' 'trunk'
#  'trunk' 'trunk' 'head' 'trunk' 'trunk' 'trunk' 'misc' 'misc' 'trunk'
#  'lower extremities' 'trunk' 'head' 'trunk' 'lower extremities' 'head'
#  'upper extremities' 'multiple body parts' 'head' 'upper extremities'
#  'lower extremities' 'trunk' 'misc' 'lower extremities'
#  'lower extremities' 'head' 'misc' 'upper extremities' 'upper extremities'
#  'upper extremities' 'multiple body parts' 'head' 'lower extremities'
#  'trunk' 'misc' 'trunk' 'trunk' 'trunk' 'lower extremities'
#  'upper extremities' 'upper extremities' 'trunk' 'misc'
#  'upper extremities' 'lower extremities' 'upper extremities'
#  'upper extremities' 'lower extremities' 'head' 'multiple body parts'
#  'misc' 'head' 'multiple body parts' 'upper extremities'
#  'multiple body parts' 'head' 'head' 'upper extremities' 'trunk' 'trunk'
#  'head' 'misc' 'lower extremities' 'upper extremities' 'misc' 'misc'
#  'misc' 'misc' 'misc' 'misc' 'misc' 'misc' 'misc' 'misc' 'head' 'misc'
#  'misc' 'misc' 'misc' 'misc' 'misc' 'misc' 'misc' 'upper extremities'
#  'upper extremities' 'upper extremities']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   test.loc[:, 'Body Part - Hierarchy 1'] = pd.Series([bodyparts[i] for i in bodypart_preds])

# %%
test.head()
# Out:
#                                      LossDescription ResultingInjuryDesc  \
# 0                                                NaN                 NaN
# 1                                                NaN                 NaN
# 2                                                NaN                 NaN
# 3  EE was getting out of the truck and twisted he...                 NaN
# 4  Worker was making a delivery and her right han...                 NaN
#
#   PartInjuredDesc          Cause - Hierarchy 1 Body Part - Hierarchy 1  Index
# 0           Thumb  caught in, under or between       upper extremities      5
# 1       Lower Arm  caught in, under or between       upper extremities     17
# 2         Abdomen                         misc                   trunk     20
# 3             NaN  caught in, under or between       lower extremities     47
# 4             NaN            includes freezing       upper extremities     48

# %%
test.to_csv("test.csv")
